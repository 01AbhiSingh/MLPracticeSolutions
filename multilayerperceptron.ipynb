# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

# %%
class perceptron(nn.Module):
    def __init__(self, input_features: int, output_features: int):
        super(perceptron, self).__init__()

        self. weights = nn.Parameter(torch.zeros(input_features,1))
        self.bias = nn.Parameter(torch.zeros(output_features))

    def forward(self, x: torch.Tensor) -> torch.tensor:
        x.float()

        linear_output = torch.matmul(x, self.weights) + self.bias
        prediction = (linear_output) > 0
        return torch.relu(linear_output)

# %%
class mlp(nn.Module):
    def __init__(self, input_layers : int, hidden_layers : int, num_classes: int):
        super(mlp, self).__init__()

        self.hidden_layer1 = perceptron(input_layers, hidden_layers)
        self.activation_layer1 = nn.ReLU()
        self.output_layer2 = perceptron(hidden_layers, num_classes)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = self.hidden_layer1(x)
        x = self.activation_layer1(x)
        x = self.output_layer2(x)

        return x

# %%
INPUT_DIM = 10
HIDDEN_DIM = 20
OUTPUT_DIM = 3
LEARNING_RATE = 0.0000000000000000000000001
BATCH_SIZE = 32
EPOCHS = 10

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available else 'cpu')
print(DEVICE)
# Out:
# cuda

# %%
num_samples = 1000
x = torch.randn(num_samples, INPUT_DIM)
y = torch.randint(0, OUTPUT_DIM,(num_samples,))

# %%
dataset = TensorDataset(x, y)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
model =  mlp (INPUT_DIM, HIDDEN_DIM, OUTPUT_DIM). to(DEVICE)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)

# %%
for epoch in range(EPOCHS):
    model.train()
    total_loss = 0
    for batch_x, batch_y in dataloader:
        batch_x, batch_y = batch_x.to(DEVICE), batch_y.to(DEVICE)

        output = model(batch_x)
        loss = criterion(output, batch_y)

        optimizer.zero_grad()#clear grad
        loss.backward()#compute grad
        optimizer.step()#update weights

        total_loss += loss.item()

        avg_loss = total_loss / len(dataloader)
        print(f"Epoch [{epoch+1}/{EPOCHS}], Average Loss: {avg_loss:.4f}")
# Out:
# Epoch [1/10], Average Loss: 0.0343
# Epoch [1/10], Average Loss: 0.0687
# Epoch [1/10], Average Loss: 0.1030
# Epoch [1/10], Average Loss: 0.1373
# Epoch [1/10], Average Loss: 0.1717
# Epoch [1/10], Average Loss: 0.2060
# Epoch [1/10], Average Loss: 0.2403
# Epoch [1/10], Average Loss: 0.2747
# Epoch [1/10], Average Loss: 0.3090
# Epoch [1/10], Average Loss: 0.3433
# Epoch [1/10], Average Loss: 0.3776
# Epoch [1/10], Average Loss: 0.4120
# Epoch [1/10], Average Loss: 0.4463
# Epoch [1/10], Average Loss: 0.4806
# Epoch [1/10], Average Loss: 0.5150
# Epoch [1/10], Average Loss: 0.5493
# Epoch [1/10], Average Loss: 0.5836
# Epoch [1/10], Average Loss: 0.6180
# Epoch [1/10], Average Loss: 0.6523
# Epoch [1/10], Average Loss: 0.6866
# Epoch [1/10], Average Loss: 0.7210
# Epoch [1/10], Average Loss: 0.7553
# Epoch [1/10], Average Loss: 0.7896
# Epoch [1/10], Average Loss: 0.8240
# Epoch [1/10], Average Loss: 0.8583
# Epoch [1/10], Average Loss: 0.8926
# Epoch [1/10], Average Loss: 0.9270
# Epoch [1/10], Average Loss: 0.9613
# Epoch [1/10], Average Loss: 0.9956
# Epoch [1/10], Average Loss: 1.0299
# Epoch [1/10], Average Loss: 1.0643
# Epoch [1/10], Average Loss: 1.0986
# Epoch [2/10], Average Loss: 0.0343
# Epoch [2/10], Average Loss: 0.0687
# Epoch [2/10], Average Loss: 0.1030
# Epoch [2/10], Average Loss: 0.1373
# Epoch [2/10], Average Loss: 0.1717
# Epoch [2/10], Average Loss: 0.2060
# Epoch [2/10], Average Loss: 0.2403
# Epoch [2/10], Average Loss: 0.2747
# Epoch [2/10], Average Loss: 0.3090
# Epoch [2/10], Average Loss: 0.3433
# Epoch [2/10], Average Loss: 0.3776
# Epoch [2/10], Average Loss: 0.4120
# Epoch [2/10], Average Loss: 0.4463
# Epoch [2/10], Average Loss: 0.4806
# Epoch [2/10], Average Loss: 0.5150
# Epoch [2/10], Average Loss: 0.5493
# Epoch [2/10], Average Loss: 0.5836
# Epoch [2/10], Average Loss: 0.6180
# Epoch [2/10], Average Loss: 0.6523
# Epoch [2/10], Average Loss: 0.6866
# Epoch [2/10], Average Loss: 0.7210
# Epoch [2/10], Average Loss: 0.7553
# Epoch [2/10], Average Loss: 0.7896
# Epoch [2/10], Average Loss: 0.8240
# Epoch [2/10], Average Loss: 0.8583
# Epoch [2/10], Average Loss: 0.8926
# Epoch [2/10], Average Loss: 0.9270
# Epoch [2/10], Average Loss: 0.9613
# Epoch [2/10], Average Loss: 0.9956
# Epoch [2/10], Average Loss: 1.0299
# Epoch [2/10], Average Loss: 1.0643
# Epoch [2/10], Average Loss: 1.0986
# Epoch [3/10], Average Loss: 0.0343
# Epoch [3/10], Average Loss: 0.0687
# Epoch [3/10], Average Loss: 0.1030
# Epoch [3/10], Average Loss: 0.1373
# Epoch [3/10], Average Loss: 0.1717
# Epoch [3/10], Average Loss: 0.2060
# Epoch [3/10], Average Loss: 0.2403
# Epoch [3/10], Average Loss: 0.2747
# Epoch [3/10], Average Loss: 0.3090
# Epoch [3/10], Average Loss: 0.3433
# Epoch [3/10], Average Loss: 0.3776
# Epoch [3/10], Average Loss: 0.4120
# Epoch [3/10], Average Loss: 0.4463
# Epoch [3/10], Average Loss: 0.4806
# Epoch [3/10], Average Loss: 0.5150
# Epoch [3/10], Average Loss: 0.5493
# Epoch [3/10], Average Loss: 0.5836
# Epoch [3/10], Average Loss: 0.6180
# Epoch [3/10], Average Loss: 0.6523
# Epoch [3/10], Average Loss: 0.6866
# Epoch [3/10], Average Loss: 0.7210
# Epoch [3/10], Average Loss: 0.7553
# Epoch [3/10], Average Loss: 0.7896
# Epoch [3/10], Average Loss: 0.8240
# Epoch [3/10], Average Loss: 0.8583
# Epoch [3/10], Average Loss: 0.8926
# Epoch [3/10], Average Loss: 0.9270
# Epoch [3/10], Average Loss: 0.9613
# Epoch [3/10], Average Loss: 0.9956
# Epoch [3/10], Average Loss: 1.0299
# Epoch [3/10], Average Loss: 1.0643
# Epoch [3/10], Average Loss: 1.0986
# Epoch [4/10], Average Loss: 0.0343
# Epoch [4/10], Average Loss: 0.0687
# Epoch [4/10], Average Loss: 0.1030
# Epoch [4/10], Average Loss: 0.1373
# Epoch [4/10], Average Loss: 0.1717
# Epoch [4/10], Average Loss: 0.2060
# Epoch [4/10], Average Loss: 0.2403
# Epoch [4/10], Average Loss: 0.2747
# Epoch [4/10], Average Loss: 0.3090
# Epoch [4/10], Average Loss: 0.3433
# Epoch [4/10], Average Loss: 0.3776
# Epoch [4/10], Average Loss: 0.4120
# Epoch [4/10], Average Loss: 0.4463
# Epoch [4/10], Average Loss: 0.4806
# Epoch [4/10], Average Loss: 0.5150
# Epoch [4/10], Average Loss: 0.5493
# Epoch [4/10], Average Loss: 0.5836
# Epoch [4/10], Average Loss: 0.6180
# Epoch [4/10], Average Loss: 0.6523
# Epoch [4/10], Average Loss: 0.6866
# Epoch [4/10], Average Loss: 0.7210
# Epoch [4/10], Average Loss: 0.7553
# Epoch [4/10], Average Loss: 0.7896
# Epoch [4/10], Average Loss: 0.8240
# Epoch [4/10], Average Loss: 0.8583
# Epoch [4/10], Average Loss: 0.8926
# Epoch [4/10], Average Loss: 0.9270
# Epoch [4/10], Average Loss: 0.9613
# Epoch [4/10], Average Loss: 0.9956
# Epoch [4/10], Average Loss: 1.0299
# Epoch [4/10], Average Loss: 1.0643
# Epoch [4/10], Average Loss: 1.0986
# Epoch [5/10], Average Loss: 0.0343
# Epoch [5/10], Average Loss: 0.0687
# Epoch [5/10], Average Loss: 0.1030
# Epoch [5/10], Average Loss: 0.1373
# Epoch [5/10], Average Loss: 0.1717
# Epoch [5/10], Average Loss: 0.2060
# Epoch [5/10], Average Loss: 0.2403
# Epoch [5/10], Average Loss: 0.2747
# Epoch [5/10], Average Loss: 0.3090
# Epoch [5/10], Average Loss: 0.3433
# Epoch [5/10], Average Loss: 0.3776
# Epoch [5/10], Average Loss: 0.4120
# Epoch [5/10], Average Loss: 0.4463
# Epoch [5/10], Average Loss: 0.4806
# Epoch [5/10], Average Loss: 0.5150
# Epoch [5/10], Average Loss: 0.5493
# Epoch [5/10], Average Loss: 0.5836
# Epoch [5/10], Average Loss: 0.6180
# Epoch [5/10], Average Loss: 0.6523
# Epoch [5/10], Average Loss: 0.6866
# Epoch [5/10], Average Loss: 0.7210
# Epoch [5/10], Average Loss: 0.7553
# Epoch [5/10], Average Loss: 0.7896
# Epoch [5/10], Average Loss: 0.8240
# Epoch [5/10], Average Loss: 0.8583
# Epoch [5/10], Average Loss: 0.8926
# Epoch [5/10], Average Loss: 0.9270
# Epoch [5/10], Average Loss: 0.9613
# Epoch [5/10], Average Loss: 0.9956
# Epoch [5/10], Average Loss: 1.0299
# Epoch [5/10], Average Loss: 1.0643
# Epoch [5/10], Average Loss: 1.0986
# Epoch [6/10], Average Loss: 0.0343
# Epoch [6/10], Average Loss: 0.0687
# Epoch [6/10], Average Loss: 0.1030
# Epoch [6/10], Average Loss: 0.1373
# Epoch [6/10], Average Loss: 0.1717
# Epoch [6/10], Average Loss: 0.2060
# Epoch [6/10], Average Loss: 0.2403
# Epoch [6/10], Average Loss: 0.2747
# Epoch [6/10], Average Loss: 0.3090
# Epoch [6/10], Average Loss: 0.3433
# Epoch [6/10], Average Loss: 0.3776
# Epoch [6/10], Average Loss: 0.4120
# Epoch [6/10], Average Loss: 0.4463
# Epoch [6/10], Average Loss: 0.4806
# Epoch [6/10], Average Loss: 0.5150
# Epoch [6/10], Average Loss: 0.5493
# Epoch [6/10], Average Loss: 0.5836
# Epoch [6/10], Average Loss: 0.6180
# Epoch [6/10], Average Loss: 0.6523
# Epoch [6/10], Average Loss: 0.6866
# Epoch [6/10], Average Loss: 0.7210
# Epoch [6/10], Average Loss: 0.7553
# Epoch [6/10], Average Loss: 0.7896
# Epoch [6/10], Average Loss: 0.8240
# Epoch [6/10], Average Loss: 0.8583
# Epoch [6/10], Average Loss: 0.8926
# Epoch [6/10], Average Loss: 0.9270
# Epoch [6/10], Average Loss: 0.9613
# Epoch [6/10], Average Loss: 0.9956
# Epoch [6/10], Average Loss: 1.0299
# Epoch [6/10], Average Loss: 1.0643
# Epoch [6/10], Average Loss: 1.0986
# Epoch [7/10], Average Loss: 0.0343
# Epoch [7/10], Average Loss: 0.0687
# Epoch [7/10], Average Loss: 0.1030
# Epoch [7/10], Average Loss: 0.1373
# Epoch [7/10], Average Loss: 0.1717
# Epoch [7/10], Average Loss: 0.2060
# Epoch [7/10], Average Loss: 0.2403
# Epoch [7/10], Average Loss: 0.2747
# Epoch [7/10], Average Loss: 0.3090
# Epoch [7/10], Average Loss: 0.3433
# Epoch [7/10], Average Loss: 0.3776
# Epoch [7/10], Average Loss: 0.4120
# Epoch [7/10], Average Loss: 0.4463
# Epoch [7/10], Average Loss: 0.4806
# Epoch [7/10], Average Loss: 0.5150
# Epoch [7/10], Average Loss: 0.5493
# Epoch [7/10], Average Loss: 0.5836
# Epoch [7/10], Average Loss: 0.6180
# Epoch [7/10], Average Loss: 0.6523
# Epoch [7/10], Average Loss: 0.6866
# Epoch [7/10], Average Loss: 0.7210
# Epoch [7/10], Average Loss: 0.7553
# Epoch [7/10], Average Loss: 0.7896
# Epoch [7/10], Average Loss: 0.8240
# Epoch [7/10], Average Loss: 0.8583
# Epoch [7/10], Average Loss: 0.8926
# Epoch [7/10], Average Loss: 0.9270
# Epoch [7/10], Average Loss: 0.9613
# Epoch [7/10], Average Loss: 0.9956
# Epoch [7/10], Average Loss: 1.0299
# Epoch [7/10], Average Loss: 1.0643
# Epoch [7/10], Average Loss: 1.0986
# Epoch [8/10], Average Loss: 0.0343
# Epoch [8/10], Average Loss: 0.0687
# Epoch [8/10], Average Loss: 0.1030
# Epoch [8/10], Average Loss: 0.1373
# Epoch [8/10], Average Loss: 0.1717
# Epoch [8/10], Average Loss: 0.2060
# Epoch [8/10], Average Loss: 0.2403
# Epoch [8/10], Average Loss: 0.2747
# Epoch [8/10], Average Loss: 0.3090
# Epoch [8/10], Average Loss: 0.3433
# Epoch [8/10], Average Loss: 0.3776
# Epoch [8/10], Average Loss: 0.4120
# Epoch [8/10], Average Loss: 0.4463
# Epoch [8/10], Average Loss: 0.4806
# Epoch [8/10], Average Loss: 0.5150
# Epoch [8/10], Average Loss: 0.5493
# Epoch [8/10], Average Loss: 0.5836
# Epoch [8/10], Average Loss: 0.6180
# Epoch [8/10], Average Loss: 0.6523
# Epoch [8/10], Average Loss: 0.6866
# Epoch [8/10], Average Loss: 0.7210
# Epoch [8/10], Average Loss: 0.7553
# Epoch [8/10], Average Loss: 0.7896
# Epoch [8/10], Average Loss: 0.8240
# Epoch [8/10], Average Loss: 0.8583
# Epoch [8/10], Average Loss: 0.8926
# Epoch [8/10], Average Loss: 0.9270
# Epoch [8/10], Average Loss: 0.9613
# Epoch [8/10], Average Loss: 0.9956
# Epoch [8/10], Average Loss: 1.0299
# Epoch [8/10], Average Loss: 1.0643
# Epoch [8/10], Average Loss: 1.0986
# Epoch [9/10], Average Loss: 0.0343
# Epoch [9/10], Average Loss: 0.0687
# Epoch [9/10], Average Loss: 0.1030
# Epoch [9/10], Average Loss: 0.1373
# Epoch [9/10], Average Loss: 0.1717
# Epoch [9/10], Average Loss: 0.2060
# Epoch [9/10], Average Loss: 0.2403
# Epoch [9/10], Average Loss: 0.2747
# Epoch [9/10], Average Loss: 0.3090
# Epoch [9/10], Average Loss: 0.3433
# Epoch [9/10], Average Loss: 0.3776
# Epoch [9/10], Average Loss: 0.4120
# Epoch [9/10], Average Loss: 0.4463
# Epoch [9/10], Average Loss: 0.4806
# Epoch [9/10], Average Loss: 0.5150
# Epoch [9/10], Average Loss: 0.5493
# Epoch [9/10], Average Loss: 0.5836
# Epoch [9/10], Average Loss: 0.6180
# Epoch [9/10], Average Loss: 0.6523
# Epoch [9/10], Average Loss: 0.6866
# Epoch [9/10], Average Loss: 0.7210
# Epoch [9/10], Average Loss: 0.7553
# Epoch [9/10], Average Loss: 0.7896
# Epoch [9/10], Average Loss: 0.8240
# Epoch [9/10], Average Loss: 0.8583
# Epoch [9/10], Average Loss: 0.8926
# Epoch [9/10], Average Loss: 0.9270
# Epoch [9/10], Average Loss: 0.9613
# Epoch [9/10], Average Loss: 0.9956
# Epoch [9/10], Average Loss: 1.0299
# Epoch [9/10], Average Loss: 1.0643
# Epoch [9/10], Average Loss: 1.0986
# Epoch [10/10], Average Loss: 0.0343
# Epoch [10/10], Average Loss: 0.0687
# Epoch [10/10], Average Loss: 0.1030
# Epoch [10/10], Average Loss: 0.1373
# Epoch [10/10], Average Loss: 0.1717
# Epoch [10/10], Average Loss: 0.2060
# Epoch [10/10], Average Loss: 0.2403
# Epoch [10/10], Average Loss: 0.2747
# Epoch [10/10], Average Loss: 0.3090
# Epoch [10/10], Average Loss: 0.3433
# Epoch [10/10], Average Loss: 0.3776
# Epoch [10/10], Average Loss: 0.4120
# Epoch [10/10], Average Loss: 0.4463
# Epoch [10/10], Average Loss: 0.4806
# Epoch [10/10], Average Loss: 0.5150
# Epoch [10/10], Average Loss: 0.5493
# Epoch [10/10], Average Loss: 0.5836
# Epoch [10/10], Average Loss: 0.6180
# Epoch [10/10], Average Loss: 0.6523
# Epoch [10/10], Average Loss: 0.6866
# Epoch [10/10], Average Loss: 0.7210
# Epoch [10/10], Average Loss: 0.7553
# Epoch [10/10], Average Loss: 0.7896
# Epoch [10/10], Average Loss: 0.8240
# Epoch [10/10], Average Loss: 0.8583
# Epoch [10/10], Average Loss: 0.8926
# Epoch [10/10], Average Loss: 0.9270
# Epoch [10/10], Average Loss: 0.9613
# Epoch [10/10], Average Loss: 0.9956
# Epoch [10/10], Average Loss: 1.0299
# Epoch [10/10], Average Loss: 1.0643
# Epoch [10/10], Average Loss: 1.0986
